# %% [markdown]
# Import Data from CSV file

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

file_path = './promedios.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Ahora tenemos que dividir los datos en Target y Variabes, para convertir en tensores

# %%
cm = df.corr()

print(cm)

plt.figure(figsize=(8, 6))

# Create a heatmap of the correlation matrix
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)

# Display the heatmap
plt.title('Correlation Matrix')
plt.show()
# Out:
#               Departamento  Semestre      Edad  Promedio
# Departamento      1.000000 -0.356358 -0.108940 -0.373310
# Semestre         -0.356358  1.000000  0.810385  0.202634
# Edad             -0.108940  0.810385  1.000000  0.043474
# Promedio         -0.373310  0.202634  0.043474  1.000000
