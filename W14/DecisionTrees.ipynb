# %%
import pandas as pd
import tensorflow as tf
import numpy as np

file_path = './W14-01_data.csv'
data = pd.read_csv(file_path)

# %%
print(data.head())

# 1. Extract the features and labels
X = data[['X1', 'X2']]
Y = data[['Y']]

# 2. Divide train and test
from sklearn.model_selection import train_test_split
X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2)

# Print the first 5 rows of the features and labels
print(X.head())
print(Y.head())
# Out:
#    Unnamed: 0        X1        X2  Y
# 0           0  1.962859  2.439449  0
# 1           1  2.179087  2.774685  0
# 2           2  0.685858  0.439305  0
# 3           3  1.866534  0.223129  0
# 4           4  2.013203  3.585046  1
#             X1        X2
# 3835  2.433981  2.268431
# 789   0.790406  0.671644
# 2795  0.913136  0.852260
# 4719  3.149105  1.807964
# 1904  0.479246  1.939616
#       Y
# 3835  0
# 789   0
# 2795  0
# 4719  0
# 1904  0

# %%
# Create a Decisopn Tree model
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

tree_clf = DecisionTreeClassifier(random_state=0, criterion='gini', 
                                  splitter='best', max_depth=1 )
tree_clf.fit(X, Y)
# Out:
# DecisionTreeClassifier(max_depth=1, random_state=0)

# %%
# Visualize the Decision Tree
import matplotlib.pyplot as plt
plt.figure(figsize=(25,20))
tree.plot_tree(tree_clf, feature_names=['X1', 'X2'], class_names=['0', '1'], filled=True)
plt.show()

# %%
input = np.array([[0.6717,3.76341], [0.5, 5.5], [0.5, 0.5], [0.5, 1.5]])
output = tree_clf.predict(input)
print(output)

# Test accuracy
from sklearn.metrics import accuracy_score
Y_pred = tree_clf.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print('Accuracy: ', accuracy)
# Out:
# [1 1 0 0]
# Accuracy:  0.8248175182481752
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
